# %%
import pandas as pd

# %%
new_cases = pd.read_csv('../data/Public-Dataset-County-New.csv')
new_cases
# Out:
#              DATE      COUNTY  TOTAL_CASES  NEW_CASES  TOTAL_CONFIRMED  \
# 0        3/5/2020      Shelby          NaN        NaN              NaN
# 1        3/5/2020  Williamson          1.0        NaN              NaN
# 2        3/6/2020    Davidson          NaN        NaN              NaN
# 3        3/6/2020  Williamson          1.0        0.0              NaN
# 4        3/7/2020  Williamson          1.0        0.0              NaN
# ...           ...         ...          ...        ...              ...
# 22794  11/12/2020       Wayne       1673.0        9.0           1634.0
# 22795  11/12/2020     Weakley       1792.0       12.0           1580.0
# 22796  11/12/2020       White       1465.0       13.0           1317.0
# 22797  11/12/2020  Williamson       8892.0      115.0           8469.0
# 22798  11/12/2020      Wilson       5832.0       81.0           5661.0
#
#        NEW_CONFIRMED  TOTAL_PROBABLE  NEW_PROBABLE  POS_TESTS  NEW_POS_TESTS  \
# ...

# %%
new_cases = new_cases.fillna(0)

# %%
davidson = new_cases[new_cases['COUNTY']=='Davidson']

# %%
davidson
# Out:
#              DATE    COUNTY  TOTAL_CASES  NEW_CASES  TOTAL_CONFIRMED  \
# 2        3/6/2020  Davidson          NaN        NaN              NaN
# 5        3/8/2020  Davidson          1.0        NaN              NaN
# 8        3/9/2020  Davidson          1.0        0.0              NaN
# 15      3/10/2020  Davidson          2.0        1.0              NaN
# 21      3/11/2020  Davidson          2.0        0.0              NaN
# ...           ...       ...          ...        ...              ...
# 22332   11/8/2020  Davidson      35139.0      264.0          34759.0
# 22429   11/9/2020  Davidson      35655.0      516.0          35263.0
# 22526  11/10/2020  Davidson      35938.0      283.0          35528.0
# 22623  11/11/2020  Davidson      36414.0      476.0          35995.0
# 22720  11/12/2020  Davidson      36757.0      343.0          36315.0
#
#        NEW_CONFIRMED  TOTAL_PROBABLE  NEW_PROBABLE  POS_TESTS  NEW_POS_TESTS  \
# ...

# %%
davidson['NEW_CASES'].sum()
# Out:
# 36756.0

# %%
davidson[davidson['DATE']=='10/29/2020']
# Out:
#              DATE    COUNTY  TOTAL_CASES  NEW_CASES  TOTAL_CONFIRMED  \
# 21362  10/29/2020  Davidson      32679.0      196.0          32375.0
#
#        NEW_CONFIRMED  TOTAL_PROBABLE  NEW_PROBABLE  POS_TESTS  NEW_POS_TESTS  \
# 21362          188.0           304.0           8.0    40552.0          219.0
#
#        ...  NEW_DEATHS  TOTAL_DEATHS  NEW_RECOVERED  TOTAL_RECOVERED  \
# 21362  ...        -1.0         345.0            NaN              NaN
#
#        NEW_ACTIVE  TOTAL_ACTIVE  NEW_INACTIVE_RECOVERED  \
# 21362       -51.0        2411.0                   248.0
#
#        TOTAL_INACTIVE_RECOVERED  NEW_HOSPITALIZED  TOTAL_HOSPITALIZED
# 21362                   29923.0               3.0              1192.0
#
# [1 rows x 24 columns]
